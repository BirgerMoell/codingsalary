# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import sys  

import numpy as np
import matplotlib

reload(sys)  
sys.setdefaultencoding('utf8')


sns.set_style("whitegrid")

data = pd.read_csv('salary.csv')

data.columns = ['role', 'salary', 'years']
data['role'] = data.role.str.lower()
data['years'] = data.years.apply(pd.to_numeric)

data.head()

# %%
matplotlib.style.use('seaborn-dark-palette')

font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 22}

matplotlib.rc('font', **font)

# %%
from scipy import stats

fs = (15, 8.27)
fig, ax = plt.subplots(figsize=fs)

# get coeffs of linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(data['years'],data['salary'])

# use line_kws to set line label for legend
ax = sns.regplot(x="years", y="salary", data=data, color='#3D9977', 
 line_kws={'label':"salary = {0:.0f} * years + {1:.0f}".format(slope, intercept)})

# plot legend
ax.legend()

plt.show()

# %%
fs = (15, 8.27)
fig, ax = plt.subplots(figsize=fs)
sns.distplot(data.salary)
ax.set_xlim([0, 250000])
plt.yticks([], [])

fs = (15, 8.27)
fig, ax = plt.subplots(figsize=fs)
sns.distplot(data.years)
ax.set_xlim([0, 40])
plt.yticks([], [])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
role_salary = data.groupby('role').salary.describe()
role_salary = role_salary.loc[role_salary['count'] >= 5].sort_values('50%')

fs = (15, 8.27)
fig, ax = plt.subplots(figsize=fs)
ax.bar(range(len(role_salary)), role_salary['50%'], color='#3D9970')
plt.xticks(0.5 + np.arange(len(role_salary)), role_salary.index, rotation='vertical')
plt.title('Medianlön', fontsize=20)

# %%
role_salary = data.groupby('role').salary.describe()
role_salary = role_salary.loc[role_salary['count'] >= 5].sort_values('mean')

fs = (15, 8.27)
fig, ax = plt.subplots(figsize=fs)
ax.bar(range(len(role_salary)), role_salary['mean'], color='#3D9970')
plt.xticks(0.5 + np.arange(len(role_salary)), role_salary.index, rotation='vertical')
plt.title('Medellön', fontsize=20)

# %%
fs = (15, 8.27)
fig, ax = plt.subplots(figsize=fs)
sns.regplot("years", "salary", data=data, lowess=True, ax=ax)
ax.set_xlim([-0.5, 40])
ax.set_ylim([0, 210000])
# Out:
# (0, 210000)

# %%
fs = (15, 8.27)
fig, ax = plt.subplots(figsize=fs)
sns.regplot("years", "salary", data=data, lowess=True, ax=ax)
ax.set_xlim([-0.3, 10.3])
ax.set_ylim([0, 100000])
#ax.set_yscale('log')
# Out:
# (0, 100000)

# %%
translationer = {'front end utvecklare': 'frontendutvecklare',
'frontend utvecklare': 'frontendutvecklare',
'software utvecklare': 'utvecklare'}
def trans(x):
    if x in translationer:
        return translationer[x]
    return x

data.role = data.role.astype('string').map(lambda x: x.replace('developer', 'utvecklare')).map(trans)
role_salary = data.groupby('role').salary.describe()

# %%
role_salary.sort_values('count', ascending=False).head(20)
# Out:
#                     count          mean           std      min      25%  \
# role
# systemutvecklare     49.0  35533.938776   7414.713931  24000.0  32000.0
# utvecklare           39.0  48230.769231  29933.849471  27000.0  35100.0
# frontendutvecklare   29.0  35116.551724   8808.637107  23000.0  29000.0
# webbutvecklare       22.0  31801.363636   8694.833877  10000.0  26625.0
# konsult              11.0  47163.636364  16420.857026  25000.0  33250.0
# senior utvecklare    11.0  46909.090909  10690.692639  35000.0  40500.0
# lead utvecklare       9.0  47333.333333  12654.050735  35000.0  38500.0
# programmerare         8.0  45662.500000  13077.673177  28000.0  37600.0
# data scientist        8.0  45425.000000   8199.782227  35300.0  40750.0
# systemutvecklare      8.0  39825.000000   6388.102781  32000.0  37000.0
# software engineer     7.0  39285.714286   8445.201512  30000.0  33000.0
# fullstack             6.0  39916.666667  12093.042077  29000.0  32000.0
# utvecklare            6.0  35750.000000   5636.931790  28000.0  32250.0
# team lead             4.0  51500.000000   6350.852961  45000.0  48000.0
# tech lead             4.0  43250.000000   4031.128874  40000.0  40750.0
# lösningsarkitekt      4.0  50250.000000   5439.056291  43000.0  48250.0
# cto                   4.0  46250.000000  14930.394056  25000.0  43750.0
# junior utvecklare     4.0  31500.000000   3696.845502  27000.0  30000.0
# it konsult            3.0  58650.000000  28202.703771  27500.0  46750.0
# ios utvecklare        3.0  31666.666667  11930.353445  18000.0  27500.0
#
#                         50%      75%       max
# role
# systemutvecklare    33000.0  39000.0   61250.0
# utvecklare          42000.0  48250.0  202000.0
# frontendutvecklare  33000.0  37200.0   57680.0
# webbutvecklare      31500.0  36750.0   49000.0
# konsult             50000.0  60000.0   72000.0
# senior utvecklare   47000.0  49500.0   75000.0
# lead utvecklare     40000.0  58000.0   68000.0
# programmerare       45250.0  51000.0   70000.0
# data scientist      43500.0  50575.0   60000.0
# systemutvecklare    37600.0  40725.0   52500.0
# software engineer   37500.0  43750.0   54000.0
# fullstack           39000.0  40000.0   62500.0
# utvecklare          35500.0  40625.0   42000.0
# team lead           50500.0  54000.0   60000.0
# tech lead           42000.0  44500.0   49000.0
# lösningsarkitekt    51000.0  53000.0   56000.0
# cto                 50000.0  52500.0   60000.0
# junior utvecklare   31500.0  33000.0   36000.0
# it konsult          66000.0  74225.0   82450.0
# ios utvecklare      37000.0  38500.0   40000.0

# %%
data.describe()
# Out:
#               salary       years
# count     451.000000  451.000000
# mean    42294.283814    7.271508
# std     15965.936850    7.000876
# min     10000.000000    0.000000
# 25%     33000.000000    2.000000
# 50%     39000.000000    5.000000
# 75%     48000.000000   10.000000
# max    202000.000000   38.000000

# %%
data.role.describe()
# Out:
# count                  451
# unique                 208
# top       systemutvecklare
# freq                    49
# Name: role, dtype: object

# %%
N = 5
f, axes = plt.subplots(N, 1, figsize=(17, 22), sharex=True)
sns.despine(left=True)
for year in range(1, N+1):
    sns.distplot(data[data.years == year].salary, ax=axes[year-1], axlabel='')
plt.setp(axes, yticks=[])
plt.tight_layout()
plt.suptitle('Salary distribution (years worked)')

# %%
fs = (15, 8.27)
fig, ax = plt.subplots(figsize=fs)
#plt.hist(data[data.years == 1].salary, '.')
n, bins, patches = plt.hist(data[data.years < 10].salary, 50)
plt.show()
